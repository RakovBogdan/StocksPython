# %%
# %run analyzer.py

# %%
analyzer1 = Analyzer("2012-01-01", "2016-01-01")
analyzer1.add_stock('BA')
analyzer1.add_stock('AAPL')

# %%
for stock in analyzer1.stocks:
    print(stock.prices)
# Out:
#              Adj_Close
# Date
# 2012-01-31   65.943003
# 2012-02-29   67.016001
# 2012-03-31   66.497398
# 2012-04-30   68.670165
# 2012-05-31   62.611112
# 2012-06-30   66.829559
# 2012-07-31   66.478771
# 2012-08-31   64.607853
# 2012-09-30   62.974559
# 2012-10-31   63.739176
# 2012-11-30   67.635708
# 2012-12-31   68.619103
# 2013-01-31   67.262382
# 2013-02-28   70.475488
# 2013-03-31   78.677772
# 2013-04-30   83.773269
# 2013-05-31   91.215520
# 2013-06-30   94.365965
# 2013-07-31   96.816312
# 2013-08-31   96.165594
# 2013-09-30  108.732268
# 2013-10-31  120.762221
# 2013-11-30  124.685121
# 2013-12-31  126.765529
# 2014-01-31  116.335630
# 2014-02-28  120.417037
# 2014-03-31  117.213264
# 2014-04-30  120.510441
# 2014-05-31  127.037024
# 2014-06-30  119.504033
# 2014-07-31  113.163923
# 2014-08-31  119.834834
# 2014-09-30  120.382974
# 2014-10-31  118.048652
# 2014-11-30  127.725778
# 2014-12-31  123.562047
# 2015-01-31  138.192143
# 2015-02-28  144.283762
# ...

# %%
import matplotlib.pylab as plt
for stock in analyzer1.stocks:
    ax = stock.prices['Adj_Close'].plot(label = stock.ticker)
plt.legend(loc = 2, fontsize = 14)
ax.set_ylabel('Adjusted Close')
plt.show()
